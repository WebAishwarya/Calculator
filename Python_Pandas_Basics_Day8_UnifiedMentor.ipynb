# %% [markdown]
# <a href="https://colab.research.google.com/github/WebAishwarya/Data-Analyst_Unified-Mentor/blob/main/Python_Pandas_Basics_Day8_UnifiedMentor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY 8
#
# ---

# %% [markdown]
# # 8.1 Pandas Series & DataFrame

# %% [markdown]
# # Pandas Series
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd

# %%
# Series Method

series = pd.Series([1, 7, 2, 8, 5])

print(series)
# Out:
# 0    1
# 1    7
# 2    2
# 3    8
# 4    5
# dtype: int64

# %%
# Series Method with Index

series = pd.Series([1, 7, 2, 8, 5], index = ["a", "b", "c","d","e"])

print(series)
# Out:
# a    1
# b    7
# c    2
# d    8
# e    5
# dtype: int64

# %%
# Accessing Series elements

print(series[1])
print(series["e"])
# Out:
# 7
# 5

# %% [markdown]
# # Pandas DataFrame
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.

# %%
# DataFrame Method on list

data = pd.DataFrame([1,2,3,4,5])
print(data)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
# DataFrame using Dictionary

data = pd.DataFrame({'Name':['Tom', 'Jack', 'Steve', 'Ricky','Sam','Will','Root'],
                     'Age':[28,34,29,42,17,17,45]})
data.head(10)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
# 4    Sam   17
# 5   Will   17
# 6   Root   45

# %%
# DataFrame with Index

data = pd.DataFrame({'Name':['Tom', 'Jack', 'Steve', 'Ricky','Sam','Will','Root'],
                     'Age':[28,34,29,42,17,17,45]}, index=['C1','C2','C3','C4','C5','C6','C7'])
data.head(10)
# Out:
#      Name  Age
# C1    Tom   28
# C2   Jack   34
# C3  Steve   29
# C4  Ricky   42
# C5    Sam   17
# C6   Will   17
# C7   Root   45

# %%
# Column Selection

data['Name']
# Out:
# C1      Tom
# C2     Jack
# C3    Steve
# C4    Ricky
# C5      Sam
# C6     Will
# C7     Root
# Name: Name, dtype: object

# %%
data['Age']
# Out:
# C1    28
# C2    34
# C3    29
# C4    42
# C5    17
# C6    17
# C7    45
# Name: Age, dtype: int64

# %%
data.head(10)
# Out:
#      Name  Age
# C1    Tom   28
# C2   Jack   34
# C3  Steve   29
# C4  Ricky   42
# C5    Sam   17
# C6   Will   17
# C7   Root   45

# %%
# Row Selection

print(data.loc['C4','Age'])     # .loc - location of the row - [Row, Col] - passing labels string
print(data.iloc[3,0])           # .iloc - integer location of the row - passing integer
# Out:
# 42
# Ricky

# %% [markdown]
# ---
#
# # 8.2 Pandas Concate & Indexing Methods

# %% [markdown]
# # Pandas Concatenation
#
# It is used to concatenate pandas objects along a particular axis with optional set logic along the other axes.

# %%
names = pd.DataFrame({'Name':['Tom', 'Jack', 'Steve', 'Ricky','Sam','Will','Root']})
ages = pd.DataFrame({'Age':[28,34,29,42,17,17,45]})

# %%
names
# Out:
#     Name
# 0    Tom
# 1   Jack
# 2  Steve
# 3  Ricky
# 4    Sam
# 5   Will
# 6   Root

# %%
ages
# Out:
#    Age
# 0   28
# 1   34
# 2   29
# 3   42
# 4   17
# 5   17
# 6   45

# %%
pd.concat([names, ages], axis = 1)        # Concatenation
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42
# 4    Sam   17
# 5   Will   17
# 6   Root   45

# %%
names2 = pd.DataFrame({'Name':['Joe', 'Pope', 'Buttler', 'Ben','James','Cook']})

# %%
pd.concat([names, names2])                # Concatenation
# Out:
#       Name
# 0      Tom
# 1     Jack
# 2    Steve
# 3    Ricky
# 4      Sam
# 5     Will
# 6     Root
# 0      Joe
# 1     Pope
# 2  Buttler
# 3      Ben
# 4    James
# 5     Cook

# %% [markdown]
# # Pandas Indexing
#
# loc() , iloc(), Filtering methods

# %% [markdown]
# **loc() & iloc() Methods**

# %%
data
# Out:
#      Name  Age
# C1    Tom   28
# C2   Jack   34
# C3  Steve   29
# C4  Ricky   42
# C5    Sam   17
# C6   Will   17
# C7   Root   45

# %%
print(data.loc['C2','Name'])
print(data.iloc[5,0])
# Out:
# Jack
# Will

# %% [markdown]
# **Filtering Method**

# %%
data
# Out:
#      Name  Age
# C1    Tom   28
# C2   Jack   34
# C3  Steve   29
# C4  Ricky   42
# C5    Sam   17
# C6   Will   17
# C7   Root   45

# %%
# data['Name']
data[['Name','Age']]
# Out:
#      Name  Age
# C1    Tom   28
# C2   Jack   34
# C3  Steve   29
# C4  Ricky   42
# C5    Sam   17
# C6   Will   17
# C7   Root   45

# %%
data[data['Age'] > 40]
# Out:
#      Name  Age
# C4  Ricky   42
# C7   Root   45

# %%
data[data['Age'] >= 18][['Name']]
# Out:
#      Name
# C1    Tom
# C2   Jack
# C3  Steve
# C4  Ricky
# C7   Root
